# %% [markdown]
# # Data Cleaning
#
# We will try to see if there are any missing values and drop rows and columns if necessary

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib

# %matplotlib inline

# %%
df = pd.read_csv("../data/processed/cleaned.csv")

df.head()
# Out:
#         community_name  population  householdsize  racepctblack  racePctWhite  \
# 0         Lakewoodcity        0.19           0.33          0.02          0.90
# 1          Tukwilacity        0.00           0.16          0.12          0.74
# 2         Aberdeentown        0.00           0.42          0.49          0.56
# 3  Willingborotownship        0.04           0.77          1.00          0.08
# 4    Bethlehemtownship        0.01           0.55          0.02          0.95
#
#    racePctAsian  racePctHisp  agePct12t21  agePct12t29  agePct16t24  \
# 0          0.12         0.17         0.34         0.47         0.29
# 1          0.45         0.07         0.26         0.59         0.35
# 2          0.17         0.04         0.39         0.47         0.28
# 3          0.12         0.10         0.51         0.50         0.34
# 4          0.09         0.05         0.38         0.38         0.23
#
#            ...           MedOwnCostPctIncNoMtg:  NumInShelters:  NumStreet:  \
# ...

# %%
nanSums = df.isnull().sum()

nanSums
# Out:
# community_name            0
# population                0
# householdsize             0
# racepctblack              0
# racePctWhite              0
# racePctAsian              0
# racePctHisp               0
# agePct12t21               0
# agePct12t29               0
# agePct16t24               0
# agePct65up                0
# numbUrban                 0
# pctUrban                  0
# medIncome                 0
# pctWWage                  0
# pctWFarmSelf              0
# pctWInvInc                0
# pctWSocSec                0
# pctWPubAsst               0
# pctWRetire                0
# medFamInc                 0
# perCapInc                 0
# whitePerCap               0
# blackPerCap               0
# indianPerCap              0
# AsianPerCap               0
# OtherPerCap               0
# HispPerCap                0
# NumUnderPov               0
# PctPopUnderPov            0
#                          ..
# PctPersDenseHous:         0
# PctHousLess3BR:           0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1994 entries, 0 to 1993
# Data columns (total 91 columns):
# community_name            1994 non-null object
# population                1994 non-null float64
# householdsize             1994 non-null float64
# racepctblack              1994 non-null float64
# racePctWhite              1994 non-null float64
# racePctAsian              1994 non-null float64
# racePctHisp               1994 non-null float64
# agePct12t21               1994 non-null float64
# agePct12t29               1994 non-null float64
# agePct16t24               1994 non-null float64
# agePct65up                1994 non-null float64
# numbUrban                 1994 non-null float64
# pctUrban                  1994 non-null float64
# medIncome                 1994 non-null float64
# pctWWage                  1994 non-null float64
# pctWFarmSelf              1994 non-null float64
# pctWInvInc                1994 non-null float64
# ...
